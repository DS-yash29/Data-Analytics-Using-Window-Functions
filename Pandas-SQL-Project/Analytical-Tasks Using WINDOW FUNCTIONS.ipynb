# %% [markdown]
# # Using Window Functions to perform deeper analytical tasks

# %%
import pandas as pd
import mysql.connector
import matplotlib.pyplot as plt
conn = mysql.connector.connect(host='127.0.0.1',user='root',password='*****',database='smartphones')

# %% [markdown]
# 1. Select Smartphones along with average price of thier corresponding brands

# %%
q1 = "SELECT brand_name,model,price,ROUND(AVG(price) OVER (PARTITION BY brand_name),2)  AS 'Avg-Price' FROM sp"

# %%
pd.read_sql_query(q1,con=conn).sample(40)
# Out:
# C:\Users\itCare\AppData\Local\Temp\ipykernel_201100\4218380659.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query(q1,con=conn).sample(40)
#     brand_name                                 model   price  Avg-Price
# 186   motorola                    Motorola Edge Plus   57999   21587.88
# 582      tecno                        Tecno Camon 19   14746   15054.81
# 669       vivo                           Vivo V20 SE   19000   21114.28
# 500    samsung  Samsung Galaxy A52 (8GB RAM + 128GB)   22494   29290.48
# 323       oppo               OPPO Reno 6 Pro Plus 5G   44990   25768.34
# 606      tecno                   Tecno Spark Go 2022    6249   15054.81
# 234    oneplus        OnePlus 10T (16GB RAM + 256GB)   55999   32177.43
# 464     royole                      Royole FlexPai 2  109999  129999.00
# ...

# %% [markdown]
# 2. Most Costliest Phone of each brand

# %%
q1='''WITH CTE AS 
(
    SELECT brand_name,model,price ,MAX(price) OVER (partition by brand_name)  AS max_price FROM sp
)
SELECT * FROM CTE WHERE price = max_price
'''

# %%
pd.read_sql_query(q1,con=conn)
# Out:
# C:\Users\itCare\AppData\Local\Temp\ipykernel_201100\2003521103.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query(q1,con=conn)
#    brand_name                                   model   price  max_price
# 0       apple           Apple iPhone 13 Pro Max (1TB)  179900     179900
# 1        asus                 Asus ROG Phone 6 Pro 5G   89999      89999
# 2   blackview                    Blackview BV5200 Pro    8990       8990
# 3         blu                              BLU F91 5G   14990      14990
# 4        cola                              Cola Phone   14999      14999
# 5      doogee                            Doogee V Max   45999      45999
# 6      gionee                          Gionee M12 Pro    7499       7499
# 7      google                      Google Pixel 6 Pro   54300      54300
# ...

# %% [markdown]
# 3. Top 10  Phones Based on  Price

# %%
q3 = "SELECT model,price,rating ,RANK() OVER (ORDER BY price DESC) AS rank_ FROM sp"

# %%
pd.read_sql_query(q3,con=conn).head(10)
# Out:
# C:\Users\itCare\AppData\Local\Temp\ipykernel_201100\3027341769.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query(q3,con=conn).head(10)
#                                     model   price  rating  rank_
# 0                   Vertu Signature Touch  650000    62.0      1
# 1  Xiaomi Redmi K20 Pro Signature Edition  480000    88.0      2
# 2        Huawei Mate 50 RS Porsche Design  239999    81.0      3
# 3           Apple iPhone 13 Pro Max (1TB)  179900    86.0      4
# 4                        Huawei Mate Xs 2  162990    89.0      5
# 5                     Royole FlexPai 3 5G  149999    87.0      6
# 6               Apple iPhone 13 Pro (1TB)  147900    84.0      7
# 7         Apple iPhone 13 Pro Max (256GB)  139900    84.0      8
# 8                             OPPO X 2021  134999    86.0      9
# ...

# %% [markdown]
# 4. Top Rated Phone for each brand

# %%
q4 = '''WITH CTE AS (SELECT brand_name,model,rating , RANK() OVER(PARTITION BY brand_name ORDER BY rating) AS rank_ FROM sp) SELECT * FROM CTE WHERE rank_ = 1'''

# %%
pd.read_sql_query(q4,con=conn)
# Out:
# C:\Users\itCare\AppData\Local\Temp\ipykernel_201100\1640408611.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query(q4,con=conn)
#    brand_name                        model  rating  rank_
# 0       apple               Apple iPhone 9    61.0      1
# 1        asus               Asus ZenFone 9    86.0      1
# 2        asus             Asus ROG Phone 6    86.0      1
# 3   blackview         Blackview BV5200 Pro    67.0      1
# 4         blu                   BLU F91 5G    85.0      1
# 5        cola                   Cola Phone    74.0      1
# 6      doogee                   Doogee S99    84.0      1
# 7      gionee               Gionee M12 Pro    67.0      1
# 8      google           Google Pixel 3a XL    67.0      1
# 9       honor                Honor Play 30    68.0      1
# ...
